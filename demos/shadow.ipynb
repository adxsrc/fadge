# %%
# %load_ext autoreload
# %autoreload 2

from fadge.shadow import *

from matplotlib import pyplot as plt

# %%
for a in [0, 0.5, 0.75, 0.9375, 1, 1.0625, 1.25, 2, 4, 8]:
    plt.plot(*shadow(a))

plt.xlim(- 7, 17)
plt.ylim(-12, 12)
plt.gca().set_aspect('equal')
