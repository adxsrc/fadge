# %%
# %load_ext autoreload
# %autoreload 2

from fadge.bounds import *

from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = np.linspace(-3, 3, num=1001)

plt.plot(a, reh1(a), label='Inner Event Horizon')
plt.plot(a, reh2(a), label='Outer Event Horizon')
plt.plot(a, rph1(a), label='Inner bound of photon orbits')
plt.plot(a, rph2(a), label='Outer bound of photon orbits')
plt.plot(a, rmb1(a), label='Inner marginally bound')
plt.plot(a, rmb2(a), label='Outer marginally bound')
plt.plot(a, rms1(a), label='Inner marginally stable orbit')
plt.plot(a, rms2(a), label='Outer marginally stable orbit')

plt.legend(bbox_to_anchor=[1,1])
