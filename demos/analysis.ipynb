# %%
import h5py
from matplotlib import pyplot as plt

# %%
# "Shell out" to run `fadge`

! fadge grrt --full --setup axis  1.125 90
# Out:
# Fadge: general relativistic ray tracing
#     aspin       = 1.12
#     inclination = 90
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# There is no event horizon
# /Users/ckc/Library/Python/3.10/lib/python/site-packages/jax/experimental/maps.py:497: UserWarning: xmap is an experimental feature and probably has bugs!
#   warn("xmap is an experimental feature and probably has bugs!")
# jit(masked_do); input: Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float64[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float64[2,4,1024])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████| 100/100 [08:25<00:00,  5.95s/it, lambda=-2.25e+04, dlambda=-1.14e+04]
# target = -20000.0 exceeded; SKIP

# %%
with h5py.File('axis_a1.12_i90.h5') as h:
    l = h['l'][:]
    f = h['f'][:]
    
print(f.shape)
# Out:
# (9138, 2, 4, 1024)

# %%
plt.plot(f[:,0,1,::64], f[:,0,2,::64])
plt.gca().set_aspect('equal')
plt.xlim(-5,5)
plt.ylim(-5,5)
# Out:
# (-5.0, 5.0)
