# %% [markdown]
# # Geodesic Demo

# %% [markdown]
# First, we import the necessary modules.

# %%
# %load_ext autoreload
# %autoreload 2

from fadge import GRRT
from jax   import numpy as np

from matplotlib import pyplot as plt
from itertools  import product

# %%
fs = {}

for a, q in [
    (-0.9,0),
    (-0.8,0.5),
    (-0.7,0.7),
    (0,0),
    (0,0.5),
    (0,1),
    (0.9,0),
    (0.8,0.5),
    (0.7,0.7),
]:
    grrt = GRRT(aspin=a, qcharge=q, atol=1e-3, rtol=0, names={'ind':'lambda'})
    grrt.set_cam(1e4, 90, 0)
    grrt.set_axis(fov=16, n=32)
    l, f = grrt.geode()    
    fs[(a, q)] = f
# Out:
# Radius of outer event horizon: 1.43589
# /Users/ckc/Library/Python/3.10/lib/python/site-packages/jax/experimental/maps.py:460: UserWarning: xmap is an experimental feature and probably has bugs!
#   warn("xmap is an experimental feature and probably has bugs!")
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████████████████████████████████████████████████████| 100/100 [00:02<00:00, 36.02it/s, lambda=-2.14e+04, dlambda=-2.69e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 1.3316624
# /Users/ckc/Library/Python/3.10/lib/python/site-packages/jax/experimental/maps.py:460: UserWarning: xmap is an experimental feature and probably has bugs!
#   warn("xmap is an experimental feature and probably has bugs!")
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████████████████████████████████████████████████████| 100/100 [00:02<00:00, 36.51it/s, lambda=-2.21e+04, dlambda=-2.72e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 1.1414213
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████████████████████████████████████████████████████| 100/100 [00:03<00:00, 24.56it/s, lambda=-2.02e+04, dlambda=-2.33e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 2.0
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|███████████████████████████████████████████████████| 100/100 [00:00<00:00, 115.83it/s, lambda=-2.16e+04, dlambda=-2.75e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 1.8660254
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|███████████████████████████████████████████████████| 100/100 [00:00<00:00, 123.25it/s, lambda=-2.22e+04, dlambda=-2.82e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 1.0
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████████████████████████████████████████████████████| 100/100 [00:01<00:00, 71.03it/s, lambda=-2.03e+04, dlambda=-2.39e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 1.43589
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████████████████████████████████████████████████████| 100/100 [00:02<00:00, 39.31it/s, lambda=-2.08e+04, dlambda=-2.44e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 1.3316624
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████████████████████████████████████████████████████| 100/100 [00:02<00:00, 38.90it/s, lambda=-2.21e+04, dlambda=-2.72e+03]
# target = -20000.0 exceeded; SKIP
# Radius of outer event horizon: 1.1414213
# jit(masked_do); input: Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)> Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)> [Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>, Traced<ShapedArray(float32[2,4,32])>with<DynamicJaxprTrace(level=0/1)>]
# 100%|████████████████████████████████████████████████████| 100/100 [00:03<00:00, 26.19it/s, lambda=-2.06e+04, dlambda=-2.45e+03]
# target = -20000.0 exceeded; SKIP

# %%
fig, axes = plt.subplots(3, 3, figsize=(18,18))

for i, ((a,q),f) in enumerate(fs.items()):
    fx = f[:,0,1]
    fy = f[:,0,2]
    fz = f[:,0,3]
    m  = fx[0,:]*fx[0,:] + fy[0,:]*fy[0,:] + fz[0,:]*fz[0,:] > 10

    ax = axes[divmod(i,3)]
    for k in range(32):
        ax.plot(fx[:,k], fy[:,k], '-', color='r' if m[k] else 'k')

    ax.set_title(f'a={a}, q={q}')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_xlim(-20,20)
    ax.set_ylim(-20,20)
    ax.set_aspect('equal')
